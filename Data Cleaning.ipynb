# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/DELL/Downloads/Google_Play_Store_Data/Google-Playstore.csv")
df.head()
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
# 1            5000.0              7662  True    0.0  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2312944 entries, 0 to 2312943
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   App Name           object
#  1   App Id             object
#  2   Category           object
#  3   Rating             float64
#  4   Rating Count       float64
#  5   Installs           object
#  6   Minimum Installs   float64
#  7   Maximum Installs   int64
#  8   Free               bool
#  9   Price              float64
#  10  Currency           object
#  11  Size               object
#  12  Minimum Android    object
#  13  Developer Id       object
#  14  Developer Website  object
#  15  Developer Email    object
#  16  Released           object
#  17  Last Updated       object
#  18  Content Rating     object
#  19  Privacy Policy     object
#  20  Ad Supported       bool
#  21  In App Purchases   bool
#  22  Editors Choice     bool
#  23  Scraped Time       object
# ...

# %%
df.isnull().sum()
# Out:
# App Name                  5
# App Id                    0
# Category                  0
# Rating                22883
# Rating Count          22883
# Installs                107
# Minimum Installs        107
# Maximum Installs          0
# Free                      0
# Price                     0
# Currency                135
# Size                    196
# Minimum Android        6530
# Developer Id             33
# Developer Website    760835
# Developer Email          31
# Released              71053
# Last Updated              0
# Content Rating            0
# Privacy Policy       420953
# Ad Supported              0
# In App Purchases          0
# Editors Choice            0
# Scraped Time              0
# dtype: int64

# %%
# Treat rows with null values appropriately
# Drop rows missing
df = df.dropna(subset=['Currency', 'App Name', 'Developer Email', 'Size'])


# Fill missing values with meaningful replacements
df['Rating'].fillna(df['Rating'].median(), inplace=True)  # Use median rating for missing ratings
df['Rating Count'].fillna(0, inplace=True)
df['Installs'].fillna(0, inplace=True)
df['Minimum Installs'].fillna(0, inplace=True)
df['Minimum Android'].fillna("Varies with device", inplace=True)
df['Developer Id'].fillna("Unknown Developer", inplace=True)
df['Developer Website'].fillna("Unknown Website", inplace=True)
df['Released'].fillna("Unknown", inplace=True)
df['Privacy Policy'].fillna("No Privacy Policy", inplace=True)

# Final check
print(df.isna().sum())
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2664\3493248949.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Rating'].fillna(df['Rating'].median(), inplace=True)  # Use median rating for missing ratings
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2664\3493248949.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Check unique values for potential errors or data input errors
print("Unique Content Ratings:", df['Content Rating'].unique())
print("Unique Free Status Value:", df['Free'].unique())
print("Unique Editors Choice Values:", df['Editors Choice'].unique())
print("Unique Ad-Supported Values:", df['Ad Supported'].unique())
print("Unique In-App Purchases Values:", df['In App Purchases'].unique())
# Out:
# Unique Content Ratings: ['Everyone' 'Teen' 'Mature 17+' 'Everyone 10+' 'Adults only 18+' 'Unrated']
# Unique Free Status Value: [ True False]
# Unique Editors Choice Values: [False  True]
# Unique Ad-Supported Values: [False  True]
# Unique In-App Purchases Values: [False  True]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2312578 entries, 0 to 2312943
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   App Name           object
#  1   App Id             object
#  2   Category           object
#  3   Rating             float64
#  4   Rating Count       float64
#  5   Installs           object
#  6   Minimum Installs   float64
#  7   Maximum Installs   int64
#  8   Free               bool
#  9   Price              float64
#  10  Currency           object
#  11  Size               object
#  12  Minimum Android    object
#  13  Developer Id       object
#  14  Developer Website  object
#  15  Developer Email    object
#  16  Released           object
#  17  Last Updated       object
#  18  Content Rating     object
#  19  Privacy Policy     object
#  20  Ad Supported       bool
#  21  In App Purchases   bool
#  22  Editors Choice     bool
#  23  Scraped Time       object
# ...

# %%
#cleaning size column, converting the sizes to have a uniform unit of MB
def convert_size(size):
    if pd.isna(size) or size == "Varies with device":
        return np.nan
    size = size.replace(",", "")  # Remove commas
    if size.endswith('k'):
        return float(size[:-1]) * 0.001  # Convert KB to MB
    elif size.endswith('M'):
        return float(size[:-1])  # Keep MB as is
    elif size.endswith('G'):
        return float(size[:-1]) * 1000  # Convert GB to MB
    else:
        return np.nan  # Handle unexpected values

df['Size'] = df['Size'].apply(convert_size)

# %%
# Check for duplicates
duplicate_count = df.duplicated().sum()
print(f"Total Duplicate Rows: {duplicate_count}")
# Out:
# Total Duplicate Rows: 0

# %%
# Save the cleaned file for further use

df.to_csv('Google-Playstore-data-Cleaned.csv', index = False)
